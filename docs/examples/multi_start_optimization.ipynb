# %% [markdown]
# # Time-Optimal Gates

# %% [markdown]
# First, we aim to find the fastest possible pulse realizing a CZ gate on two atoms in the perfect Rydberg blockade regime (for a fixed number of 4 pulse parameters).
# For this, we perform many random initializations of pulse parameters, optimize the pulses, and identify the fastest pulse that realizes the gate with a fidelity better our target fidelity.

# %%
# %pip install -q rydopt # Uncomment for installing RydOpt on Google Colab

import rydopt as ro
import numpy as np

# %% [markdown]
# First, we create the target gate object and the pulse ansatz. The Rydberg decay strength is set to zero.

# %%
gate = ro.gates.TwoQubitGate(phi=None, theta=np.pi, Vnn=float("inf"), decay=0.0)
pulse_ansatz = ro.pulses.PulseAnsatz(
    detuning_ansatz=ro.pulses.const, phase_ansatz=ro.pulses.sin_crab
)

# %% [markdown]
# Then we specify upper and lower bounds for the random initialization of pulse parameters.

# %%
min_initial_params = (6, (-1,), (-1, -1), ())
max_initial_params = (8, (1,), (1, 1), ())

# %% [markdown]
# We perform 60 random parameter initializations, running in parallel on 4 CPU cores. We decide to return the optimization history of all runs.

# %%
opt_result = ro.optimization.multi_start_optimize(
    gate,
    pulse_ansatz,
    min_initial_params,
    max_initial_params,
    num_steps=300,
    tol=1e-8,
    num_initializations=60,
    num_processes=4,
    return_history=True,
    return_all=True,
)
# Out:
# Started optimization using 4 processes
# Step 000000 [process01]: min infidelity = 6.226978e-02, converged = 0 / 15
# Step 000000 [process00]: min infidelity = 3.563031e-02, converged = 0 / 15
# Step 000000 [process02]: min infidelity = 2.512357e-01, converged = 0 / 15
# Step 000020 [process01]: min infidelity = 6.223137e-04, converged = 0 / 15
# Step 000000 [process03]: min infidelity = 2.820294e-02, converged = 0 / 15
# Step 000020 [process00]: min infidelity = 5.864469e-05, converged = 0 / 15
# Step 000020 [process02]: min infidelity = 8.931390e-03, converged = 0 / 15
# Step 000040 [process01]: min infidelity = 3.620228e-04, converged = 0 / 15
# Step 000060 [process01]: min infidelity = 1.025286e-05, converged = 0 / 15
# Step 000020 [process03]: min infidelity = 6.854101e-04, converged = 0 / 15
# Step 000040 [process00]: min infidelity = 2.805914e-05, converged = 0 / 15
# Step 000040 [process02]: min infidelity = 2.024516e-03, converged = 0 / 15
# Step 000080 [process01]: min infidelity = 8.656358e-06, converged = 0 / 15
# Step 000040 [process03]: min infidelity = 2.439527e-04, converged = 0 / 15
# Step 000100 [process01]: min infidelity = 3.118571e-07, converged = 0 / 15
# Step 000060 [process00]: min infidelity = 4.331323e-05, converged = 0 / 15
# Step 000120 [process01]: min infidelity = 5.697065e-08, converged = 0 / 15
# Step 000060 [process02]: min infidelity = 3.508157e-05, converged = 0 / 15
# Step 000060 [process03]: min infidelity = 6.858606e-06, converged = 0 / 15
# Step 000140 [process01]: min infidelity = 4.193537e-09, converged = 1 / 15
# Step 000080 [process00]: min infidelity = 2.597671e-06, converged = 0 / 15
# Step 000160 [process01]: min infidelity = 2.574483e-09, converged = 4 / 15
# Step 000080 [process02]: min infidelity = 2.266538e-05, converged = 0 / 15
# Step 000180 [process01]: min infidelity = 8.867618e-11, converged = 12 / 15
# Step 000080 [process03]: min infidelity = 4.759730e-07, converged = 0 / 15
# Step 000100 [process00]: min infidelity = 5.333120e-07, converged = 0 / 15
# Step 000198 [process01]: min infidelity = 3.818013e-11, converged = 15 / 15
# Step 000100 [process02]: min infidelity = 3.030887e-06, converged = 0 / 15
# Step 000100 [process03]: min infidelity = 3.544048e-07, converged = 0 / 15
# Step 000120 [process00]: min infidelity = 2.744427e-08, converged = 0 / 15
# Step 000120 [process02]: min infidelity = 4.073355e-07, converged = 0 / 15
# Step 000120 [process03]: min infidelity = 3.784113e-08, converged = 0 / 15
# Step 000140 [process00]: min infidelity = 6.438479e-10, converged = 3 / 15
# Step 000140 [process02]: min infidelity = 5.329039e-09, converged = 1 / 15
# Step 000140 [process03]: min infidelity = 8.719039e-09, converged = 1 / 15
# Step 000160 [process00]: min infidelity = 1.168793e-09, converged = 4 / 15
# Step 000160 [process02]: min infidelity = 6.638164e-09, converged = 3 / 15
# Step 000160 [process03]: min infidelity = 7.304402e-10, converged = 2 / 15
# Step 000180 [process00]: min infidelity = 1.328821e-10, converged = 11 / 15
# Step 000180 [process02]: min infidelity = 2.227705e-09, converged = 10 / 15
# Step 000193 [process00]: min infidelity = 2.991496e-11, converged = 15 / 15
# Step 000180 [process03]: min infidelity = 7.545675e-11, converged = 11 / 15
# Step 000193 [process02]: min infidelity =-4.140022e-11, converged = 15 / 15
# Step 000200 [process03]: min infidelity =-2.125811e-11, converged = 14 / 15
# Step 000205 [process03]: min infidelity =-3.757394e-11, converged = 15 / 15
#
# === Optimization finished using multi-start Adam ===
#
# Duration: 10.394 seconds
# Gates with infidelity below tol=1.0e-08: 60
#
# Slowest gate:
# > infidelity <= numerical precision
# > parameters = (9.90325893467111, [-0.77242685], [ 0.39991414 -1.8545369 ], [])
# > duration = 9.90325893467111
#
# Fastest gate:
# > infidelity <= numerical precision
# > parameters = (7.611697203705309, [-0.07207042], [ 1.49240619 -0.62246543], [])
# > duration = 7.611697203705309
# > one-sided bootstrap error on duration: 0.0002

# %% [markdown]
# Finally, we plot the history of all optimization runs.

# %%
ro.characterization.plot_optimization_history(opt_result)

# %% [markdown]
# Now, we aim to find a gate pulse that minimizes the Rydberg time for a CZ gate on two atoms in the perfect Rydberg blockade regime (for a fixed number of 4 pulse parameters).
# Again, we perform many random initializations of pulse parameters, optimize the pulses in the presence of Rydberg-state decay, and identify the pulse that performs best.

# %% [markdown]
# Specify the target gate *with* decay

# %%
gate_with_decay = ro.gates.TwoQubitGate(
    phi=None, theta=np.pi, Vnn=float("inf"), decay=0.0001
)

# %% [markdown]
# Perform 60 random parameter initializations, running in parallel on 4 CPU cores.

# %%
opt_result_with_decay = ro.optimization.multi_start_optimize(
    gate_with_decay,
    pulse_ansatz,
    min_initial_params,
    max_initial_params,
    num_steps=300,
    tol=1e-8,
    num_initializations=60,
    num_processes=4,
)
# Out:
# Started optimization using 4 processes
# Step 000000 [process00]: min infidelity = 1.670751e-01, converged = 0 / 15
# Step 000000 [process03]: min infidelity = 1.547750e-02, converged = 0 / 15
# Step 000020 [process00]: min infidelity = 3.101731e-03, converged = 0 / 15
# Step 000000 [process02]: min infidelity = 2.249797e-01, converged = 0 / 15
# Step 000000 [process01]: min infidelity = 3.234736e-01, converged = 0 / 15
# Step 000020 [process03]: min infidelity = 1.397847e-03, converged = 0 / 15
# Step 000040 [process00]: min infidelity = 6.046061e-04, converged = 0 / 15
# Step 000020 [process02]: min infidelity = 6.388628e-03, converged = 0 / 15
# Step 000020 [process01]: min infidelity = 1.252514e-02, converged = 0 / 15
# Step 000040 [process03]: min infidelity = 3.555915e-04, converged = 0 / 15
# Step 000060 [process00]: min infidelity = 3.524621e-04, converged = 0 / 15
# Step 000040 [process02]: min infidelity = 3.035282e-04, converged = 0 / 15
# Step 000040 [process01]: min infidelity = 7.664802e-04, converged = 0 / 15
# Step 000060 [process03]: min infidelity = 3.016159e-04, converged = 0 / 15
# Step 000080 [process00]: min infidelity = 3.000079e-04, converged = 0 / 15
# Step 000060 [process02]: min infidelity = 3.560966e-04, converged = 0 / 15
# Step 000060 [process01]: min infidelity = 3.217965e-04, converged = 0 / 15
# Step 000080 [process03]: min infidelity = 2.947677e-04, converged = 0 / 15
# Step 000100 [process00]: min infidelity = 2.953729e-04, converged = 0 / 15
# Step 000080 [process02]: min infidelity = 2.964141e-04, converged = 0 / 15
# Step 000080 [process01]: min infidelity = 3.123892e-04, converged = 0 / 15
# Step 000100 [process03]: min infidelity = 2.939169e-04, converged = 0 / 15
# Step 000120 [process00]: min infidelity = 2.939583e-04, converged = 0 / 15
# Step 000100 [process02]: min infidelity = 2.943409e-04, converged = 0 / 15
# Step 000100 [process01]: min infidelity = 2.962697e-04, converged = 0 / 15
# Step 000120 [process03]: min infidelity = 2.939916e-04, converged = 0 / 15
# Step 000140 [process00]: min infidelity = 2.938200e-04, converged = 0 / 15
# Step 000120 [process02]: min infidelity = 2.939707e-04, converged = 0 / 15
# Step 000120 [process01]: min infidelity = 2.939426e-04, converged = 0 / 15
# Step 000140 [process03]: min infidelity = 2.937824e-04, converged = 0 / 15
# Step 000160 [process00]: min infidelity = 2.937637e-04, converged = 0 / 15
# Step 000140 [process02]: min infidelity = 2.937976e-04, converged = 0 / 15
# Step 000140 [process01]: min infidelity = 2.938173e-04, converged = 0 / 15
# Step 000160 [process03]: min infidelity = 2.937719e-04, converged = 0 / 15
# Step 000180 [process00]: min infidelity = 2.937605e-04, converged = 0 / 15
# Step 000160 [process02]: min infidelity = 2.937559e-04, converged = 0 / 15
# Step 000160 [process01]: min infidelity = 2.937891e-04, converged = 0 / 15
# Step 000180 [process03]: min infidelity = 2.937683e-04, converged = 0 / 15
# Step 000200 [process00]: min infidelity = 2.937601e-04, converged = 0 / 15
# Step 000180 [process02]: min infidelity = 2.937543e-04, converged = 0 / 15
# Step 000180 [process01]: min infidelity = 2.937558e-04, converged = 0 / 15
# Step 000200 [process03]: min infidelity = 2.937534e-04, converged = 0 / 15
# Step 000220 [process00]: min infidelity = 2.937600e-04, converged = 0 / 15
# Step 000200 [process02]: min infidelity = 2.937532e-04, converged = 0 / 15
# Step 000200 [process01]: min infidelity = 2.937557e-04, converged = 0 / 15
# Step 000220 [process03]: min infidelity = 2.937536e-04, converged = 0 / 15
# Step 000240 [process00]: min infidelity = 2.937600e-04, converged = 0 / 15
# Step 000220 [process02]: min infidelity = 2.937531e-04, converged = 0 / 15
# Step 000220 [process01]: min infidelity = 2.937551e-04, converged = 0 / 15
# Step 000240 [process03]: min infidelity = 2.937533e-04, converged = 0 / 15
# Step 000260 [process00]: min infidelity = 2.937600e-04, converged = 0 / 15
# Step 000240 [process02]: min infidelity = 2.937531e-04, converged = 0 / 15
# Step 000240 [process01]: min infidelity = 2.937550e-04, converged = 0 / 15
# Step 000260 [process03]: min infidelity = 2.937533e-04, converged = 0 / 15
# Step 000280 [process00]: min infidelity = 2.937600e-04, converged = 0 / 15
# Step 000260 [process02]: min infidelity = 2.937531e-04, converged = 0 / 15
# Step 000260 [process01]: min infidelity = 2.937550e-04, converged = 0 / 15
# Step 000280 [process03]: min infidelity = 2.937533e-04, converged = 0 / 15
# Step 000299 [process00]: min infidelity = 2.937600e-04, converged = 0 / 15
# Step 000280 [process02]: min infidelity = 2.937531e-04, converged = 0 / 15
# Step 000280 [process01]: min infidelity = 2.937550e-04, converged = 0 / 15
# Step 000299 [process03]: min infidelity = 2.937533e-04, converged = 0 / 15
# Step 000299 [process02]: min infidelity = 2.937531e-04, converged = 0 / 15
# Step 000299 [process01]: min infidelity = 2.937550e-04, converged = 0 / 15
#
# === Optimization finished using multi-start Adam ===
#
# Duration: 11.814 seconds
# Gates with infidelity below tol=1.0e-08: 0
#
# Best gate:
# > infidelity = 2.937531e-04
# > parameters = (7.7029563479670875, [0.12368825], [ 0.15436098 -0.90974181], [])
# > duration = 7.7029563479670875

# %% [markdown]
# Finally, we analyze the best performing gate.

# %%
optimized_params_with_decay = opt_result_with_decay.params
infidelity, infidelity_nodecay, ryd_time = ro.characterization.analyze_gate(
    gate_with_decay, pulse_ansatz, optimized_params_with_decay
)

print(f"Gate infidelity:             {infidelity:.4e}")
print(f"Gate infidelity (no decay):  {infidelity_nodecay:.4e}")
print(f"Rydberg time:                {ryd_time:.4f}")
# Out:
# Gate infidelity:             2.9375e-04
# Gate infidelity (no decay):  4.2979e-09
# Rydberg time:                2.9380
